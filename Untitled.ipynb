# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("/home/adithya/DAQ-Sensor/DataStored/Testingvalues/measurement0000.csv")
print(data.head)
print(data.shape)
LidarData = data[['rad','distance','x' , 'y', 'strength']]
print(LidarData)
PlotData = data[data['strength']>50]
print(PlotData)
ax = plt.subplot(001,projection = 'polar')
ax.plot(PlotData['rad'], PlotData['distance'])
ax.grid(True)
# Out:
# <bound method DataFrame.head of       Unnamed: 0  degrees  distance  strength       rad         x         y
# 0              0    0.312       6.1       191  0.005445  6.099910  0.033217
# 1              1    0.875       6.7       183  0.015272  6.699219  0.102316
# 2              2    1.375       6.6       183  0.023998  6.598100  0.158373
# 3              3    1.937       6.4       183  0.033807  6.396343  0.216324
# 4              4    2.437       6.6       183  0.042534  6.594031  0.280638
# 5              5    2.937       6.7       183  0.051260  6.691199  0.343294
# 6              6    3.437       6.2       183  0.059987  6.188848  0.371696
# 7              7    4.000       6.1       183  0.069813  6.085141  0.425514
# 8              8    4.500       6.4       183  0.078540  6.380271  0.502138
# 9              9    5.062       5.9       191  0.088349  5.876989  0.520579
# 10            10    5.562       5.9       191  0.097075  5.872222  0.571845
# ...

# %%
ls /home/adithya/DAQ-Sensor/DataStored/Testingvalues
# Out:
# measurement0000.csv  measurement0003.npy  measurement0007.csv
# measurement0000.npy  measurement0004.csv  measurement0007.npy
# measurement0001.csv  measurement0004.npy  measurement0008.csv
# measurement0001.npy  measurement0005.csv  measurement0008.npy
# measurement0002.csv  measurement0005.npy  measurement0009.csv
# measurement0002.npy  measurement0006.csv  measurement0009.npy
# measurement0003.csv  measurement0006.npy

# %%
import numpy as np
SonarMeasure = np.load("/home/adithya/DAQ-Sensor/DataStored/Testingvalues/measurement0000.npy")
print(SonarMeasure[1:10, :, :])
print(SonarMeasure.shape)
# Out:
# [[[ -15.  -81.  -11.  -61.   11.  -26.   25.    4.   23.   35.]
#   [  87.   23.   -5.  122.   58.  -88.  -74.  -72.   26.   32.]]
#
#  [[ -24. -117.  -57.  -91. -100.  -37.   55.   32.   18.   13.]
#   [  34.  -27.  -80.  103.   49. -130. -109.   13.   97.   28.]]
#
#  [[ -18.  -77.  -64.  -65. -149.  -23.   47.   38.    2.  -17.]
#   [ -41.  -58. -103.   14.    7.  -87.  -74.   91.  103.    7.]]
#
#  [[   0.   15.  -30.    9. -100.    5.    9.   21.  -15.  -36.]
#   [ -88.  -49.  -57.  -80.  -39.   13.   10.  111.   40.  -19.]]
#
#  [[  18.   99.   24.   75.   15.   30.  -36.  -12.  -25.  -31.]
#   [ -80.   -8.   24. -121.  -61.  108.   90.   56.  -47.  -35.]]
#
#  [[  23.  113.   60.   89.  117.   34.  -58.  -39.  -18.   -7.]
#   [ -15.   40.   90.  -83.  -43.  128.  109.  -34. -105.  -26.]]
#
#  [[  14.   52.   56.   46.  140.   11.  -42.  -40.    0.   20.]
#   [  57.   60.   97.   11.    3.   64.   53. -102.  -95.    0.]]
#
# ...
